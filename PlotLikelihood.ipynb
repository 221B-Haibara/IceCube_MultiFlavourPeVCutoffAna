# %%
# %pylab inline
import shelve
import os
import scipy
from scipy import signal
from scipy.stats import gaussian_kde
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
font = {'weight' : 'bold',
        'size'   :  20}

# %%
H0test = shelve.open("./outputShelve.shelve", writeback=False)
print len(H0test)
# Out:
# 1

# %%
print H0test.items
# Out:
# <bound method DbfilenameShelf.items of {'test': {'cutoff': 1000000000.0, 'gamma': 2.49, 'norm': 0.0, 'LLHR': array([[ 110.85290459,   95.16761652,  104.07756477, ...,   96.11900687,
#          110.85290459,  103.88458952],
#        [ 112.53053342,   96.73760533,  105.75187252, ...,   97.74813556,
#          112.53053342,  105.55809697],
#        [  80.97923537,   67.85730984,   74.3272136 , ...,   67.99509177,
#           80.97923537,   74.16453082],
#        ...,
#        [  93.82711985,   79.414684  ,   87.10237693, ...,   79.82063649,
#           93.82711985,   86.92163767],
#        [  96.74170447,   82.08378257,   90.00540048, ...,   82.57052317,
#           96.74170447,   89.82185198],
#        [ 106.89655388,   91.47614799,  100.12994565, ...,   92.2896159 ,
#          106.89655388,   99.93907469]])}}>

# %%
for iParam, iData in H0test.items():
        LLHR = iData["LLHR"]
        plt.hist(LLHR[0],bins=100, cumulative=False ,alpha = 0.5)
        print LLHR[0]
        plt.xlabel("-2$\Delta$ lnL")
        plt.ylabel("trial count")
        #for i in xrange(len(LLHR)):
            #print i, len(LLHR[i])
        #    plt.hist(LLHR[i],bins=50, cumulative=False ,alpha = 0.5)
# Out:
# [ 110.85290459   95.16761652  104.07756477   96.29400298  104.07756477
#   103.47467064  103.10462508  103.89150666   96.52712129  104.28511035
#    96.52376734  103.32107614  103.88990963  110.85290459  103.1167643
#   103.1167643    95.45551932  104.42915721   95.81883051   89.40631551
#   103.32107614  103.00230214   96.88515136  103.90617614   81.85344389
#   110.85290459  103.90609461  102.79620584   96.01647795  103.50237433
#    96.11263735  110.85290459  110.85290459   95.94881632  103.90609461
#    97.03767631   95.41271817  103.74586439   88.5539689   103.43429538
#    96.95809077  104.16102509   88.18383461  104.24900835   89.9604772
#   103.09610016  104.00935405   95.91077085  103.89150666   96.73881181
#    97.29555474  110.85290459   96.10258692  103.65364678  103.21232837
#    96.95054655   81.67813183  103.28188733  104.09835878  110.85290459
#    89.87686995  103.47060203   89.435028    110.85290459  103.87178818
# ...
