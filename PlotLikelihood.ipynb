# %%
# %pylab inline
import shelve
import os
import scipy
from scipy import signal
from scipy.stats import gaussian_kde
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
font = {'weight' : 'bold',
        'size'   :  20}

# %%
H0test = shelve.open("./outputShelve.shelve", writeback=False)
print len(H0test)
# Out:
# 1

# %%
X = []
Y_50 = []
Y_90 = []
for iParam, iData in H0test.items():
        LLHR = iData["LLHR"]
        EnergyBin = iData["cutoff"]
        for it,i in enumerate(LLHR):
            print  np.median(i), np.percentile(i,90),  EnergyBin[it]
            X.append(np.log10(EnergyBin[it]))
            Y_50.append(np.median(i))
            Y_90.append(np.percentile(i,90))

        plt.scatter(X,Y_50, c="red")
        plt.scatter(X,Y_90)

        plt.xlabel("log$_{10}$ rec E monopod [GeV]")
        plt.ylabel("-2$\Delta$ lnL")
# Out:
# 8.35418535685 14.5769788212 10624678.3089
# 9.09212915518 15.4785605059 12742749.857
# 7.96917644742 18.4458736496 1438449.88829
# 10.5471992078 17.2827608661 18329807.1083
# 5.09407377591 12.1350769882 2069138.08111
# 10.9577529673 18.0588393317 21983926.4886
# 4.37758687722 10.438119553 2481628.92284
# 11.9243266737 19.32637624 31622776.6017
# 4.55995271234 9.70457250515 4281332.39872
# 5.15834574718 10.3472180387 5134832.90744
# 5.90558961629 11.287833788 6158482.11066
# 7.55463613859 13.4299255467 8858667.9041
# 12.7291915805 28.1773959812 1000000.0
# 10.0912087061 23.0490151145 1199353.94621
# 9.87138543792 16.4482081936 15283067.3266
# 6.31486640185 14.791299765 1725210.54994
# 11.4589580203 18.7179101637 26366508.9873
# 4.06149694557 9.53523610504 2976351.44163
# 4.18649695613 9.29766254906 3569698.84683
# 6.71348584199 12.4058795597 7386199.82208

# %%
f, axarr = plt.subplots(20, sharex=True, sharey = True, figsize=(8,20))

for iParam, iData in H0test.items():
        LLHR = iData["LLHR"]
        EnergyBin = iData["cutoff"]
        indices = np.argsort(EnergyBin, axis=0)
        LLHR = np.array(LLHR)[indices]
        EnergyBin = np.array(EnergyBin)[indices]
        for it,i in enumerate(LLHR):
            axarr[it].hist(i,bins=100, cumulative=False ,alpha = 0.5, label=str(np.round(np.log10(EnergyBin[it]),2)))
            print str(EnergyBin[it])
            plt.xlabel("-2$\Delta$ lnL")
            plt.ylabel("trial count")
            axarr[it].legend()
# Out:
# 1000000.0
# 1199353.94621
# 1438449.88829
# 1725210.54994
# 2069138.08111
# 2481628.92284
# 2976351.44163
# 3569698.84683
# 4281332.39872
# 5134832.90744
# 6158482.11066
# 7386199.82208
# 8858667.9041
# 10624678.3089
# 12742749.857
# 15283067.3266
# 18329807.1083
# 21983926.4886
# 26366508.9873
# 31622776.6017
